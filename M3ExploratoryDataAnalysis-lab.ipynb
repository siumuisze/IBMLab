# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
df['ConvertedComp'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
df['ConvertedComp'].hist(figsize=(8,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df.groupby(['Gender']).count()
# Out:
#                                                     Respondent  MainBranch  \
# Gender
# Man                                                      10480       10480
# Man;Non-binary, genderqueer, or gender non-conf...          26          26
# Non-binary, genderqueer, or gender non-conforming           63          63
# Woman                                                      731         731
# Woman;Man                                                    9           9
# Woman;Man;Non-binary, genderqueer, or gender no...           2           2
# Woman;Non-binary, genderqueer, or gender non-co...          14          14
#
#                                                     Hobbyist  OpenSourcer  \
# Gender
# Man                                                    10480        10480
# Man;Non-binary, genderqueer, or gender non-conf...        26           26
# Non-binary, genderqueer, or gender non-conforming         63           63
# Woman                                                    731          731
# Woman;Man                                                  9            9
# Woman;Man;Non-binary, genderqueer, or gender no...         2            2
# Woman;Non-binary, genderqueer, or gender non-co...        14           14
#
#                                                     OpenSource  Employment  \
# Gender
# Man                                                      10411       10480
# Man;Non-binary, genderqueer, or gender non-conf...          26          26
# Non-binary, genderqueer, or gender non-conforming           63          63
# Woman                                                      719         731
# Woman;Man                                                    9           9
# Woman;Man;Non-binary, genderqueer, or gender no...           2           2
# Woman;Non-binary, genderqueer, or gender non-co...          14          14
#
#                                                     Country  Student  EdLevel  \
# Gender
# Man                                                   10480    10433    10381
# Man;Non-binary, genderqueer, or gender non-conf...       26       26       25
# Non-binary, genderqueer, or gender non-conforming        63       63       62
# Woman                                                   731      727      721
# Woman;Man                                                 9        9        9
# Woman;Man;Non-binary, genderqueer, or gender no...        2        2        2
# Woman;Non-binary, genderqueer, or gender non-co...       14       14       14
#
#                                                     UndergradMajor  ...  \
# Gender                                                              ...
# Man                                                           9800  ...
# Man;Non-binary, genderqueer, or gender non-conf...              26  ...
# Non-binary, genderqueer, or gender non-conforming               61  ...
# Woman                                                          686  ...
# Woman;Man                                                        8  ...
# Woman;Man;Non-binary, genderqueer, or gender no...               2  ...
# Woman;Non-binary, genderqueer, or gender non-co...              13  ...
#
#                                                     SOComm  WelcomeChange  \
# Gender
# Man                                                  10480          10401
# Man;Non-binary, genderqueer, or gender non-conf...      26             26
# Non-binary, genderqueer, or gender non-conforming       63             63
# Woman                                                  731            727
# Woman;Man                                                9              8
# Woman;Man;Non-binary, genderqueer, or gender no...       2              2
# Woman;Non-binary, genderqueer, or gender non-co...      14             14
#
#                                                     SONewContent    Age  \
# Gender
# Man                                                         8648  10214
# Man;Non-binary, genderqueer, or gender non-conf...            23     24
# Non-binary, genderqueer, or gender non-conforming             52     62
# Woman                                                        626    719
# Woman;Man                                                      9      8
# Woman;Man;Non-binary, genderqueer, or gender no...             1      2
# Woman;Non-binary, genderqueer, or gender non-co...            13     14
#
#                                                     Trans  Sexuality  \
# Gender
# Man                                                 10400      10047
# Man;Non-binary, genderqueer, or gender non-conf...     25         24
# Non-binary, genderqueer, or gender non-conforming      55         41
# Woman                                                 728        682
# Woman;Man                                               9          8
# Woman;Man;Non-binary, genderqueer, or gender no...      2          1
# Woman;Non-binary, genderqueer, or gender non-co...     13         12
#
#                                                     Ethnicity  Dependents  \
# Gender
# Man                                                      9873       10347
# Man;Non-binary, genderqueer, or gender non-conf...         26          26
# Non-binary, genderqueer, or gender non-conforming          59          63
# Woman                                                     692         726
# Woman;Man                                                   8           8
# Woman;Man;Non-binary, genderqueer, or gender no...          1           2
# Woman;Non-binary, genderqueer, or gender non-co...         13          14
#
#                                                     SurveyLength  SurveyEase
# Gender
# Man                                                        10464       10467
# Man;Non-binary, genderqueer, or gender non-conf...            26          26
# Non-binary, genderqueer, or gender non-conforming             63          63
# Woman                                                        728         730
# Woman;Man                                                      9           9
# Woman;Man;Non-binary, genderqueer, or gender no...             2           2
# Woman;Non-binary, genderqueer, or gender non-co...            14          14
#
# [7 rows x 84 columns]

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df.groupby('Gender').median()
# Out:
#                                                     Respondent  CompTotal  \
# Gender
# Man                                                    12521.5    65000.0
# Man;Non-binary, genderqueer, or gender non-conf...     13609.0    65000.0
# Non-binary, genderqueer, or gender non-conforming      11807.0    66000.0
# Woman                                                  11973.0    65000.0
# Woman;Man                                              14844.0    30000.0
# Woman;Man;Non-binary, genderqueer, or gender no...     12228.0    42350.0
# Woman;Non-binary, genderqueer, or gender non-co...     10285.0    78500.0
#
#                                                     ConvertedComp  \
# Gender
# Man                                                       57744.0
# Man;Non-binary, genderqueer, or gender non-conf...        59520.0
# Non-binary, genderqueer, or gender non-conforming         67142.0
# Woman                                                     57708.0
# Woman;Man                                                 21648.0
# Woman;Man;Non-binary, genderqueer, or gender no...        30244.0
# Woman;Non-binary, genderqueer, or gender non-co...        65535.5
#
#                                                     WorkWeekHrs  CodeRevHrs  \
# Gender
# Man                                                        40.0         4.0
# Man;Non-binary, genderqueer, or gender non-conf...         40.0         3.5
# Non-binary, genderqueer, or gender non-conforming          40.0         4.0
# Woman                                                      40.0         4.0
# Woman;Man                                                  40.0         6.0
# Woman;Man;Non-binary, genderqueer, or gender no...         60.0         4.0
# Woman;Non-binary, genderqueer, or gender non-co...         40.0         3.0
#
#                                                      Age
# Gender
# Man                                                 29.0
# Man;Non-binary, genderqueer, or gender non-conf...  28.0
# Non-binary, genderqueer, or gender non-conforming   27.0
# Woman                                               28.0
# Woman;Man                                           29.5
# Woman;Man;Non-binary, genderqueer, or gender no...  26.5
# Woman;Non-binary, genderqueer, or gender non-co...  26.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df[['Age']].describe()
# Out:
#                 Age
# count  11111.000000
# mean      30.778895
# std        7.393686
# min       16.000000
# 25%       25.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
df['Age'].hist(figsize=(8,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
df.boxplot(column='ConvertedComp')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
df1 = [x for x in df['ConvertedComp'] if np.isnan(x) == False]

q75, q25 = np.percentile(df1, [75 ,25])
iqr = q75 - q25
print (q75)
print (q25)
print (iqr)
# Out:
# 100000.0
# 26868.0
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
print("Max: ", df['ConvertedComp'].max())
print("Min: ", df['ConvertedComp'].min())
print("Upper: ", q75+1.5*iqr)
print("Lower: ", q25-1.5*iqr)
# Out:
# Max:  2000000.0
# Min:  0.0
# Upper:  209698.0
# Lower:  -82830.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
outliners = df['ConvertedComp'][((df['ConvertedComp']<(q25-1.5*iqr))|(df['ConvertedComp']>(q75+1.5*iqr)))]
outliners
# Out:
# 3         455352.0
# 13       1100000.0
# 45        229016.0
# 46       2000000.0
# 60       1000000.0
#            ...
# 11296     840000.0
# 11303    1000000.0
# 11350     300000.0
# 11353     260000.0
# 11369     701196.0
# Name: ConvertedComp, Length: 879, dtype: float64

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here

upper = np.where(df['ConvertedComp']>(q75+1.5*iqr))
lower = np.where(df['ConvertedComp']<(q25-1.5*iqr))
df.drop(upper[0],inplace = True)
df.drop(lower[0],inplace = True)
df.shape
# Out:
# (10519, 85)

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df.corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.019364       0.010878    -0.015275    0.002980
# CompTotal       -0.019364   1.000000      -0.063561     0.004975    0.017536
# ConvertedComp    0.010878  -0.063561       1.000000     0.034351   -0.088934
# WorkWeekHrs     -0.015275   0.004975       0.034351     1.000000    0.031963
# CodeRevHrs       0.002980   0.017536      -0.088934     0.031963    1.000000
# Age              0.003950   0.006371       0.401821     0.037452   -0.017961
#
#                     Age
# Respondent     0.003950
# CompTotal      0.006371
# ConvertedComp  0.401821
# WorkWeekHrs    0.037452
# CodeRevHrs    -0.017961
# Age            1.000000

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
